# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('screen_Time_Sleep.csv')
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
print(x)
# Out:
# [[1.5]
#  [2.8]
#  [4.1]
#  [3.2]
#  [5.5]
#  [7.8]
#  [9. ]
#  [6.5]
#  [3.9]
#  [8.2]]

# %%
print(y)
# Out:
# [8.2 7.5 6.9 7.3 6.  5.4 4.8 5.7 7.1 5.2]

# %%
# split the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Create the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
# Train the model
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Test the model
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [6.99089368 7.47513097]

# %%
# Visualize the result
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Truth vs Bluff(Training set)')
plt.xlabel('Screen time')
plt.ylabel('Sleep Hours')
plt.show()

# %%
# Visualize the result
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Truth vs Bluff(Testing set)')
plt.xlabel('Screen time')
plt.ylabel('Sleep Hours')
plt.grid()
plt.show()

# %% [markdown]
# # Conclusion : If Screen time increases then sleep hours decreases
